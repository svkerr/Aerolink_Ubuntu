# %% [markdown]
# This Notebook reads in daily Aerolink data and performs data analysis
#
# Use cases that we need to figure out:
#
# 1. Little variance but a consistent fetch pattern: Investigate number of fetches (e.g., lots of fetches every day == low variance, but of risk?)
#
# 2. Significant variance in fetch pattern: Calculate variances

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# Load the data set:

# %%
filename = 'fetch_daily_2009_2010'
data = np.loadtxt(filename, delimiter=',', dtype=int)

# %%
data.shape
# Out:
# (2082, 366)

# %% [markdown]
# The first column in `data` consists of badge numbers.
# Create a `numpy` array where each row is a user and 365 columns are daily fetch counts (exclude badge numbers)

# %%
fetches = data[:,1:366]

# %%
fetches.shape
# Out:
# (2082, 365)

# %% [markdown]
# Create a numpy matrix `daily_diff` to hole the diff calculations on `fetches`.
#
# Now for each observation (user), compute differences (`diffs`) for consecutive days and store in `daily_diff`. This is similar to differentian in Calculus. Caution - the array returned by `diff` is one element shorter than the fetches array.
#
# When comparing this to stock market data, each diff can be considered something like the difference between the open and closing stock price. We might want to draw upon metrics which identifies a volatile from a non-volatile stock. Volatility may be an indicator of an abnormal useage pattern.

# %%
daily_diff = np.zeros((fetches.shape[0], fetches.shape[1]-1))

# %%
for i in np.arange(fetches.shape[0]):
    daily_diff[i] = np.diff(fetches[i])

# %% [markdown]
# `dict_thresh`: Capture those row indices (user) whose fetch differences exceed some threshold value.
#
# `dict_var`: Calculate variances of the differences over 365 days. Variance is a measure of how non-consistent a user fetches.
#
# `list_var_sorted`: Sorted list from `dict_var` from highest to lowest variances (but includes index)
#
# `list_var_var`: unpacked variance values from `list_var_sorted`

# %%
import operator
threshold = 100
dict_thresh = {}
dict_var = {}
for i in np.arange(daily_diff.shape[0]):
    L = []
    dict_var[i] = np.var(daily_diff[i])
    for j in np.arange(daily_diff.shape[1]):
        if daily_diff[i][j] > threshold:
              L.append(daily_diff[i][j])
              dict_thresh[i] = L

print max(dict_var.iteritems(), key=operator.itemgetter(1))
print
list_var_sorted = sorted(dict_var.iteritems(), key=operator.itemgetter(1),reverse=True)
print list_var_sorted[0:10]
# Out:
# (690, 75237.010958821396)
#
# [(690, 75237.010958821396), (1269, 22588.021978021978), (1292, 20125.362607173047), (1651, 18456.192307692309), (360, 18010.923076923078), (810, 11562.120879120879), (787, 11305.917582417582), (1500, 9631.7472527472528), (1863, 9619.0769230769238), (1594, 7484.4450549450548)]

# %% [markdown]
# Since sorting a dictionary via `iteritems()` returns a list of (index,variance) pairs, we need to unpack the variance values to plot them.

# %%
# %precision 3
# Out:
# u'%.3f'

# %%
list_var_var= []
for i in list_var_sorted:
    x,y = i
    list_var_var.append(y)
list_var_var
# Out:
# [75237.011,
#  22588.022,
#  20125.363,
#  18456.192,
#  18010.923,
#  11562.121,
#  11305.918,
#  9631.747,
#  9619.077,
#  7484.445,
#  7271.049,
#  7251.685,
#  5666.495,
#  5368.049,
#  3784.192,
#  3149.489,
#  2536.615,
#  2459.058,
#  2294.945,
#  2288.440,
#  2283.434,
#  1916.929,
#  1847.901,
#  1772.813,
#  1303.533,
#  1263.730,
#  798.698,
#  657.560,
#  620.179,
#  583.101,
#  538.225,
#  514.346,
#  507.863,
#  364.467,
#  359.346,
#  341.973,
#  340.011,
#  337.956,
#  319.225,
#  313.500,
#  283.453,
#  280.200,
#  269.324,
#  250.016,
#  244.393,
#  244.313,
#  242.352,
#  229.705,
#  216.066,
#  215.104,
#  211.033,
#  210.549,
#  205.429,
#  196.697,
#  193.577,
#  193.519,
#  183.225,
#  179.029,
#  177.907,
#  175.610,
#  170.819,
#  164.846,
#  160.165,
#  159.176,
#  158.593,
#  156.332,
#  154.731,
#  150.819,
#  147.687,
#  146.088,
#  145.310,
#  142.764,
#  139.390,
#  138.387,
#  134.577,
#  130.451,
#  129.132,
#  128.995,
#  128.653,
#  125.187,
# ...

# %%
from pylab import *
rcParams['figure.figsize'] = 12,8
plt.plot(list_var_var[0:100])

# %% [markdown]
# Verify that above routine is working

# %%
print [ x for x in daily_diff[1863] if x > 100]
print dict[1863]
print
print [ x for x in daily_diff[690] if x > 100]
print dict[690]
# Out:
# [176.0, 1383.0, 137.0, 162.0, 142.0, 255.0, 273.0, 150.0]
# [176.0, 1383.0, 137.0, 162.0, 142.0, 255.0, 273.0, 150.0]
#
# [3395.0, 1461.0, 117.0]
# [3395.0, 1461.0, 117.0]

# %%
daily_diff[690]
# Out:
# array([    0.,     0.,     0.,     0.,    18.,    -3.,   -10.,    12.,
#          -14.,    -3.,     0.,     4.,    19.,   -16.,  3395., -3402.,
#            0.,     0.,     0.,     2.,     6.,    -6.,    -2.,     0.,
#            0.,     0.,     1.,  1461., -1453.,    -9.,     0.,     0.,
#            2.,    -1.,     4.,    -1.,    -1.,    -3.,     0.,     1.,
#            3.,    -3.,    -1.,     0.,     0.,     0.,     0.,     2.,
#            3.,    -5.,    31.,   -31.,     0.,    16.,   -10.,    -1.,
#           -5.,     0.,     0.,     0.,    25.,   -21.,     2.,    -2.,
#            1.,    -5.,     0.,     3.,    11.,   -13.,    -1.,     0.,
#            0.,     0.,     1.,     2.,    14.,   -16.,    -1.,     0.,
#            0.,     1.,     3.,     2.,    -6.,     0.,     0.,     0.,
#            0.,     3.,     0.,    -2.,     1.,    -2.,     0.,     2.,
#            1.,    11.,   -12.,    -2.,     0.,     0.,     0.,     0.,
# ...
